# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/hp/Downloads/person_fall.csv")

# %%
df
# Out:
#     Counter           In_time  Elapsed_time
# 0         0  23-04-2023 00:09            28
# 1         1  23-04-2023 00:11            13
# 2         2  23-04-2023 00:13            24
# 3         3  23-04-2023 00:15             8
# 4         4  23-04-2023 00:17            23
# 5         5  23-04-2023 00:19            18
# 6         6  23-04-2023 00:21            27
# 7         7  23-04-2023 00:23            14
# 8         8  23-04-2023 00:25            20
# 9         9  23-04-2023 00:27            22
# 10       10  23-04-2023 00:29            25
# 11       11  23-04-2023 00:31            21
# 12       12  23-04-2023 00:33            17
# 13       13  23-04-2023 00:35             7
# 14       14  23-04-2023 00:37            21
# 15       15  23-04-2023 00:39            25
# 16       16  23-04-2023 00:41            19
# 17       17  23-04-2023 00:43            20
# 18       18  23-04-2023 00:45            24
# 19       19  23-04-2023 00:47            14
# ...

# %%
df['In_date']=df['In_time'].str.split(expand=True)[0]

# %%
df['In_time']=df['In_time'].str.split(expand=True)[1]

# %%
df = df.reindex(['Counter','Elapsed_time','In_time','In_date'], axis=1)

# %%
df
# Out:
#     Counter  Elapsed_time In_time     In_date
# 0         0            28   00:09  23-04-2023
# 1         1            13   00:11  23-04-2023
# 2         2            24   00:13  23-04-2023
# 3         3             8   00:15  23-04-2023
# 4         4            23   00:17  23-04-2023
# 5         5            18   00:19  23-04-2023
# 6         6            27   00:21  23-04-2023
# 7         7            14   00:23  23-04-2023
# 8         8            20   00:25  23-04-2023
# 9         9            22   00:27  23-04-2023
# 10       10            25   00:29  23-04-2023
# 11       11            21   00:31  23-04-2023
# 12       12            17   00:33  23-04-2023
# 13       13             7   00:35  23-04-2023
# 14       14            21   00:37  23-04-2023
# 15       15            25   00:39  23-04-2023
# 16       16            19   00:41  23-04-2023
# 17       17            20   00:43  23-04-2023
# 18       18            24   00:45  23-04-2023
# ...

# %%
filtered_df = df.loc[(df['In_time'] >= '00:09:00')& (df['In_time'] < '00:12:00')]

# %%
filtered_df
# Out:
#    Counter  Elapsed_time In_time     In_date
# 1        1            13   00:11  23-04-2023

# %%
filtered_df = df.loc[(df['Elapsed_time'] >= 20)]

# %%
filtered_df
# Out:
#     Counter  Elapsed_time In_time     In_date
# 0         0            28   00:09  23-04-2023
# 2         2            24   00:13  23-04-2023
# 4         4            23   00:17  23-04-2023
# 6         6            27   00:21  23-04-2023
# 8         8            20   00:25  23-04-2023
# 9         9            22   00:27  23-04-2023
# 10       10            25   00:29  23-04-2023
# 11       11            21   00:31  23-04-2023
# 14       14            21   00:37  23-04-2023
# 15       15            25   00:39  23-04-2023
# 17       17            20   00:43  23-04-2023
# 18       18            24   00:45  23-04-2023
# 20       20            21   00:49  23-04-2023
# 22       20            22   00:14  23-04-2023
# 23       21            24   00:19  23-04-2023
# 24       22            33   00:24  23-04-2023
# 25       23            27   00:29  23-04-2023
# 26       24            21   00:34  23-04-2023
# 27       25            20   00:39  23-04-2023
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(data=filtered_df, x='In_time', y='Elapsed_time')
plt.xticks(rotation=45)
plt.show()

# %%
filtered_df = df.loc[(df['Elapsed_time'] >= 20)& (df['Elapsed_time'] <= 20)]

# %%
filtered_df
# Out:
#     Counter  Elapsed_time In_time     In_date
# 8         8            20   00:25  23-04-2023
# 17       17            20   00:43  23-04-2023
# 27       25            20   00:39  23-04-2023

# %%
sns.barplot(data=filtered_df, x='In_time', y='Elapsed_time')
plt.xticks(rotation=45)
plt.show()
